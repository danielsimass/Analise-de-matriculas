# %% [markdown]
# # Criando os nomes

# %%
# !pip3 install html5lib
# !pip3 install lxml
# Out:
# Requirement already satisfied: html5lib in c:\users\daniel\anaconda3\lib\site-packages (1.1)
# Requirement already satisfied: webencodings in c:\users\daniel\anaconda3\lib\site-packages (from html5lib) (0.5.1)
# Requirement already satisfied: six>=1.9 in c:\users\daniel\anaconda3\lib\site-packages (from html5lib) (1.15.0)
# Requirement already satisfied: lxml in c:\users\daniel\anaconda3\lib\site-packages (4.6.1)

# %%
# !pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in c:\users\daniel\anaconda3\lib\site-packages (1.3.20)

# %%
import pandas as pd
import numpy as np
import html5lib

# %%
nomes_f = pd.read_json('https://servicodados.ibge.gov.br/api/v1/censos/nomes/ranking?qtd=200&sexo=f')

# %%
nomes_m = pd.read_json('https://servicodados.ibge.gov.br/api/v1/censos/nomes/ranking?qtd=200&sexo=m')

# %%
frame = [nomes_f, nomes_m]
nomes = pd.concat(frame)['nome'].to_frame()

# %% [markdown]
# # Incluindo os Ids

# %%
np.random.seed(123)

# %%
total_alunos = len(nomes)

# %%
nomes['Id_aluno'] = np.random.permutation(total_alunos) + 1

# %% [markdown]
# ## Criando os domínios de email

# %%
dominios = ['@dominio.com.br', '@serviodoemail.com']
nomes['dominio'] = np.random.choice(dominios, total_alunos)
nomes
# Out:
#           nome  Id_aluno             dominio
# 0        MARIA       235     @dominio.com.br
# 1          ANA        43  @serviodoemail.com
# 2    FRANCISCA       304  @serviodoemail.com
# 3      ANTONIA       156  @serviodoemail.com
# 4      ADRIANA       343  @serviodoemail.com
# ..         ...       ...                 ...
# 195     WALTER       231     @dominio.com.br
# 196    ARLINDO        99  @serviodoemail.com
# 197    MICHAEL       323     @dominio.com.br
# 198     ALVARO       383  @serviodoemail.com
# 199    GEOVANE       366  @serviodoemail.com
#
# [400 rows x 3 columns]

# %% [markdown]
# ## Criando o email de cada aluno

# %%
nomes['email'] = nomes.nome.str.cat(nomes.dominio).str.lower()
nomes
# Out:
#           nome  Id_aluno             dominio                        email
# 0        MARIA       235     @dominio.com.br         maria@dominio.com.br
# 1          ANA        43  @serviodoemail.com        ana@serviodoemail.com
# 2    FRANCISCA       304  @serviodoemail.com  francisca@serviodoemail.com
# 3      ANTONIA       156  @serviodoemail.com    antonia@serviodoemail.com
# 4      ADRIANA       343  @serviodoemail.com    adriana@serviodoemail.com
# ..         ...       ...                 ...                          ...
# 195     WALTER       231     @dominio.com.br        walter@dominio.com.br
# 196    ARLINDO        99  @serviodoemail.com    arlindo@serviodoemail.com
# 197    MICHAEL       323     @dominio.com.br       michael@dominio.com.br
# 198     ALVARO       383  @serviodoemail.com     alvaro@serviodoemail.com
# 199    GEOVANE       366  @serviodoemail.com    geovane@serviodoemail.com
#
# [400 rows x 4 columns]

# %% [markdown]
# ## Criando os cursos

# %%
url = 'https://tabela-cursos.herokuapp.com/index.html'
cursos = pd.read_html(url)

# %%
cursos = cursos[0]
cursos
# Out:
#                           Nome do curso
# 0                 Lógica de programação
# 1                         Java para Web
# 2                           C# para Web
# 3                         Ruby on Rails
# 4                      Cursos de Python
# 5                         PHP com MySql
# 6                         .NET para web
# 7            Novas integrações com Java
# 8                          TDD com Java
# 9                   Código limpo com C#
# 10  Preparatório para certificação Java
# 11                      Hardware básico
# 12                Persistência com .NET
# 13                  Desenvolvendo jogos
# 14                     Análise de dados
# 15                   Estatística básica
# 16                  Internet das coisas
# 17                Programação funcional
# 18                Boas práticas em Java
# 19          Orientação objetos com Java

# %%
cursos.rename(columns={'Nome do curso' : 'Nome_do_curso'})
# Out:
#                           Nome_do_curso
# 0                 Lógica de programação
# 1                         Java para Web
# 2                           C# para Web
# 3                         Ruby on Rails
# 4                      Cursos de Python
# 5                         PHP com MySql
# 6                         .NET para web
# 7            Novas integrações com Java
# 8                          TDD com Java
# 9                   Código limpo com C#
# 10  Preparatório para certificação Java
# 11                      Hardware básico
# 12                Persistência com .NET
# 13                  Desenvolvendo jogos
# 14                     Análise de dados
# 15                   Estatística básica
# 16                  Internet das coisas
# 17                Programação funcional
# 18                Boas práticas em Java
# 19          Orientação objetos com Java

# %%
cursos['Id'] = cursos.index + 1

# %%
cursos = cursos.set_index('Id')

# %% [markdown]
# ## Matriculando alunos nos cursos de forma aleatória

# %%
nomes['matriculas'] = np.ceil(np.random.exponential(size=total_alunos) * 1.5).astype(int)

# %%
nomes.head(10)
# Out:
#         nome  Id_aluno             dominio                        email  \
# 0      MARIA       235     @dominio.com.br         maria@dominio.com.br
# 1        ANA        43  @serviodoemail.com        ana@serviodoemail.com
# 2  FRANCISCA       304  @serviodoemail.com  francisca@serviodoemail.com
# 3    ANTONIA       156  @serviodoemail.com    antonia@serviodoemail.com
# 4    ADRIANA       343  @serviodoemail.com    adriana@serviodoemail.com
# 5    JULIANA       310     @dominio.com.br       juliana@dominio.com.br
# 6     MARCIA        55     @dominio.com.br        marcia@dominio.com.br
# 7   FERNANDA       288     @dominio.com.br      fernanda@dominio.com.br
# 8   PATRICIA       379  @serviodoemail.com   patricia@serviodoemail.com
# 9      ALINE        92  @serviodoemail.com      aline@serviodoemail.com
#
#    matriculas
# 0           3
# 1           1
# 2           1
# 3           3
# 4           1
# 5           4
# 6           2
# 7           1
# 8           1
# 9           4

# %%
todas_matriculas = []
x = np.random.rand(20)
prob = x / sum(x)

# %%
for index, row in nomes.iterrows():
    id = row.Id_aluno
    matriculas = row.matriculas
    for i in range(matriculas):
        mat = [id, np.random.choice(cursos.index, p = prob)]
        todas_matriculas.append(mat)

# %%
matriculas = pd.DataFrame(todas_matriculas, columns = ['Id_aluno', 'Id_curso'])
matriculas
# Out:
#      Id_aluno  Id_curso
# 0         235        11
# 1         235        11
# 2         235         2
# 3          43        13
# 4         304        10
# ..        ...       ...
# 850       323        13
# 851       383         9
# 852       383         6
# 853       383        19
# 854       366         9
#
# [855 rows x 2 columns]

# %% [markdown]
# ## Analisando quantidade de alunos por curso

# %%
matriculas.groupby('Id_curso').count().join(cursos['Nome do curso']).rename(columns={'Id_aluno' : 'quantidade_de_alunos'})
# Out:
#           quantidade_de_alunos                        Nome do curso
# Id_curso
# 1                            8                Lógica de programação
# 2                           81                        Java para Web
# 3                           18                          C# para Web
# 4                           17                        Ruby on Rails
# 5                           24                     Cursos de Python
# 6                           68                        PHP com MySql
# 7                            4                        .NET para web
# 8                           54           Novas integrações com Java
# 9                           68                         TDD com Java
# 10                          48                  Código limpo com C#
# 11                          57  Preparatório para certificação Java
# 12                          12                      Hardware básico
# 13                          45                Persistência com .NET
# 14                          46                  Desenvolvendo jogos
# 15                          26                     Análise de dados
# 16                          71                   Estatística básica
# 17                          37                  Internet das coisas
# 18                          79                Programação funcional
# 19                          59                Boas práticas em Java
# 20                          33          Orientação objetos com Java

# %%
matricula_por_curso = matriculas.groupby('Id_curso').count().join(cursos['Nome do curso']).rename(columns={'Id_aluno' : 'quantidade_de_alunos'})

# %% [markdown]
# ## Exportando DataFrames em .csv

# %%
matricula_por_curso.to_csv('dados/matricula_por_curso.csv', index = False)
nomes.to_csv('dados/nomes.csv')
cursos.to_csv('dados/cursos.csv')

# %% [markdown]
# ## Criando o banco SQL

# %%
from sqlalchemy import create_engine, MetaData, Table

# %%
engine = create_engine('sqlite:///:memory:')

# %%
engine
# Out:
# Engine(sqlite:///:memory:)

# %%
matricula_por_curso.to_sql('matriculas', engine)

# %% [markdown]
# ## Buscando do banco SQL

# %%
query = 'select * from matriculas where quantidade_de_alunos < 20'

# %%
pd.read_sql(query, engine)
# Out:
#    Id_curso  quantidade_de_alunos          Nome do curso
# 0         1                     8  Lógica de programação
# 1         3                    18            C# para Web
# 2         4                    17          Ruby on Rails
# 3         7                     4          .NET para web
# 4        12                    12        Hardware básico

# %%
pd.read_sql_table('matriculas', engine, columns=['Nome do curso', 'quantidade_de_alunos'])
# Out:
#                           Nome do curso  quantidade_de_alunos
# 0                 Lógica de programação                     8
# 1                         Java para Web                    81
# 2                           C# para Web                    18
# 3                         Ruby on Rails                    17
# 4                      Cursos de Python                    24
# 5                         PHP com MySql                    68
# 6                         .NET para web                     4
# 7            Novas integrações com Java                    54
# 8                          TDD com Java                    68
# 9                   Código limpo com C#                    48
# 10  Preparatório para certificação Java                    57
# 11                      Hardware básico                    12
# 12                Persistência com .NET                    45
# 13                  Desenvolvendo jogos                    46
# 14                     Análise de dados                    26
# 15                   Estatística básica                    71
# 16                  Internet das coisas                    37
# 17                Programação funcional                    79
# 18                Boas práticas em Java                    59
# 19          Orientação objetos com Java                    33

# %%
muitas_matriculas = pd.read_sql_table('matriculas', engine, columns=['Nome do curso', 'quantidade_de_alunos'])

# %%
muitas_matriculas = muitas_matriculas.query('quantidade_de_alunos > 50')

# %% [markdown]
# ## Escrevendo no banco SQL

# %%
muitas_matriculas.to_sql('muitas_matriculas', con=engine)

# %%
print(engine.table_names())
# Out:
# ['matriculas', 'muitas_matriculas']

# %% [markdown]
# ## Nomes dos alunos(as) da próxima turma

# %%
id_curso = 7
proxima_turma = matriculas.query(f"Id_curso == {id_curso}")

# %%
proxima_turma
# Out:
#      Id_aluno  Id_curso
# 247       106         7
# 286        75         7
# 438        24         7
# 809       312         7

# %%
proxima_turma.set_index('Id_aluno').join(nomes.set_index('Id_aluno'))['nome'].to_frame()
# Out:
#                nome
# Id_aluno
# 106           LIVIA
# 75            NEUSA
# 24             JOAO
# 312       WANDERSON

# %%
nomes_proxima_turma = proxima_turma.set_index('Id_aluno').join(nomes.set_index('Id_aluno'))['nome'].to_frame()

# %%
nomes_proxima_turma.rename(columns = {'nome' : 'alunos do curso.NET para web'})
# Out:
#          alunos do curso.NET para web
# Id_aluno
# 106                             LIVIA
# 75                              NEUSA
# 24                               JOAO
# 312                         WANDERSON

# %% [markdown]
# ## Exportando em formato excel

# %%
nomes_proxima_turma.to_excel('dados/nomes_proxima_turma.xlsx', index=False)
